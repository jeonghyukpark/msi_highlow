# %%
import pandas as pd
import numpy as np
import msi.lgbm_msi as lgbm_msi

# %%
df = pd.read_csv('./data/msi_features.csv', index_col=0)
df = df[df['neoplastic'].notnull()]
df_case, feature_cols = lgbm_msi.preprocess_df(df)

# %%
df_case
# Out:
#          case_id_  prob_ADI_mean  prob_ADI_std  prob_ADI_max  prob_ADI_min  \
# 0    TCGA-3L-AA1B       0.000557      0.001149      0.011883  8.744755e-08
# 1    TCGA-3M-AB46       0.002674      0.026968      0.781841  2.996256e-08
# 2    TCGA-4N-A93T       0.000643      0.007404      0.178039  3.075196e-08
# 3    TCGA-5M-AAT4       0.000659      0.007448      0.148185  1.084309e-07
# 4    TCGA-5M-AAT6       0.000510      0.000963      0.020150  9.242873e-08
# ..            ...            ...           ...           ...           ...
# 639  TCGA-VQ-AA6I       0.004459      0.034302      0.647025  2.724288e-07
# 640  TCGA-VQ-AA6J       0.001289      0.012066      0.320920  1.578799e-08
# 641  TCGA-VQ-AA6K       0.001945      0.004328      0.021956  2.161115e-06
# 642  TCGA-WS-AB45       0.003278      0.008329      0.099364  5.531547e-07
# 643  TCGA-ZA-A8F6       0.001277      0.002627      0.019605  1.440491e-07
#
# ...

# %%
model_path = './data/model_weights/MSI_LGBM_5F_tcg_COAD_599d434c.pickle'

# %%
lgbm_msi.evaluate(df_case = df_case, 
                  feature_cols = feature_cols, 
                  model_path = model_path)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/base.py:333: UserWarning: Trying to unpickle estimator StandardScaler from version 1.0 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   UserWarning,
#                                           model_path                     auc  \
# 0  ./data/model_weights/MSI_LGBM_5F_tcg_COAD_599d...  0.6749 (0.6365-0.7134)
#
#    lambda  learning_rate  feature_fraction
# 0     0.1            0.1               0.8

# %%
lgbm_msi.inference(df_case = df_case, 
                   feature_cols = feature_cols, 
                   model_path = model_path)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/base.py:333: UserWarning: Trying to unpickle estimator StandardScaler from version 1.0 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   UserWarning,
#          case_id_  prob_ADI_mean  prob_ADI_std  prob_ADI_max  prob_ADI_min  \
# 0    TCGA-3L-AA1B       0.000557      0.001149      0.011883  8.744755e-08
# 1    TCGA-3M-AB46       0.002674      0.026968      0.781841  2.996256e-08
# 2    TCGA-4N-A93T       0.000643      0.007404      0.178039  3.075196e-08
# 3    TCGA-5M-AAT4       0.000659      0.007448      0.148185  1.084309e-07
# 4    TCGA-5M-AAT6       0.000510      0.000963      0.020150  9.242873e-08
# ..            ...            ...           ...           ...           ...
# ...
